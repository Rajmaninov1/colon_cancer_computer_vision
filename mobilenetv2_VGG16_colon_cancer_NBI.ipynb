# %% [markdown]
# ## **¿Qué es una endoscopia?**
#
# La endoscopia digestiva engloba diferentes procedimientos técnicos que nos permiten visualizar una gran parte del aparato digestivo. El desarrollo de estas exploraciones ha permitido, durante los últimos años, un gran avance en el estudio de las enfermedades digestivas y, más específicamente, en el manejo de algunas lesiones que hasta ahora suponían una indicación quirúrgica que, gracias a los métodos endoscópicos, se pueden tratar adecuadamente con una menor incidencia de complicaciones que la cirugía. Se realiza mediante una sonda flexible que tiene una pequeña cámara y una luz en su extremo, la cual es llamada endoscopio. Sus usos son:
#
# - Observar en detalle una zona en el interior del cuerpo
# - Tomar muestras de tejidos anormales (biopsia)
# - Tratar ciertas enfermedades
# - Extirpar tumores
# - Detener un sangrado
# - Extraer cuerpos extraños (como alimento atorado en el esófago, el conducto que conecta la garganta con el estómago)
#
# Los tipos de endoscopia son:
#
# - La anoscopia visualiza el interior del ano, la parte más baja del colon.
# - La colonoscopia visualiza el interior del colon (intestino grueso) y el recto.
# - La enteroscopia visualiza el interior del intestino delgado.
# - La CPRE (colangiopancreatografía retrógrada endoscópica) visualiza las vías biliares, pequeños conductos que drenan la vesícula biliar, el hígado y el páncreas.
# - La sigmoidoscopia visualiza dentro de la parte inferior del colon denominada colon sigmoide y el recto.
# - La endoscopia de vías digestivas altas (esofagogastroduodenoscopia o EGD) visualiza el interior del esófago, el estómago y la primera parte del intestino delgado (denominada duodeno).
# - La broncoscopia se utiliza para observar las vías respiratorias (tráquea) y los pulmones.
# - La cistoscopia se utiliza para observar el interior de la vejiga. El cistoscopio se pasa a través de la abertura de la uretra.
# - La laparoscopia se usa para examinar directamente los ovarios, el apéndice u otros órganos abdominales. El laparoscopio se introduce a través de pequeñas incisiones quirúrgicas en la zona pélvica o del vientre. Se pueden extirpar tumores u órganos en el abdomen o la pelvis.
# - La artroscopia se utiliza para mirar directamente en las articulaciones, como en la rodilla. El artroscopio se introduce a través de pequeñas incisiones quirúrgicas alrededor de la articulación. Se pueden tratar problemas de los huesos, los tendones y los ligamentos.
#
# La endoscopia gastrointestinal puede ayudar a encontrar la causa de síntomas inexplicables, como:
#
# - acidez estomacal persistente
# - sangrado
# - náuseas y vómito
# - dolor
# - problemas de deglución
# - adelgazamiento sin razón aparente
#
# La endoscopia gastrointestinal se puede usar para identificar muchas enfermedades diferentes:
#
# - reflujo gastroensofágico
# - úlceras
# - cáncer
# - inflamación o hinchazón
# - anomalías precancerosas como esófago de Barrett
# - celiaquía
# - estenosis o estrechamiento del esófago
# - obstrucciones
#
# Durante una endoscopia gastrointestinal, el médico obtiene biopsias pasando un instrumento a través del endoscopio para obtener una pequeña muestra de tejido para la prueba. Las biopsias son necesarias para diagnosticar afecciones como:
#
# - cáncer
# - celiaquía
# - gastritis
#
# ### Bibliografía
#
# - Principal, P., & médica, E. (2021). Endoscopia : MedlinePlus enciclopedia médica. Retrieved 23 November 2021, from https://medlineplus.gov/spanish/ency/article/003338.htm
# - (2021). Retrieved 23 November 2021, from http://www.scdigestologia.org/docs/patologies/es/endoscopia_digestiva_es.pdf
# - Endoscopia gastrointestinal | NIDDK. (2017). Retrieved 23 November 2021, from https://www.niddk.nih.gov/health-information/informacion-de-la-salud/pruebas-diagnosticas/endoscopia-esofagogastroduodenal

# %% [markdown]
# ___

# %% [markdown]
# ## **¿Qué son las imágenes de banda estrecha o Narrow band imaging (NBI)**
#
# El NBI o imagen de banda estrecha es un novedoso sistema de visualización endoscópica que posibilita una valoración en detalle de la superficie mucosa y su patrón vascular. A pesar de los avances notables que han tenido las endoscopias se encuentra una dificultad en parte a que la luz blanca con que cuentan estos instrumentos no permite identificar áreas de displasia (Término que describe la presencia de células anormales en un tejido o un órgano. La displasia no es cáncer, pero a veces se vuelve cáncer). Al no tener forma de identificar el área afectada, el diagnóstico recae en la toma aleatoria de biopsias. Esto agrega complejidad al procedimiento y tiene un rendimiento limitado, ya que en ocasiones las muestras no son representativas o caen fuera del área lesional.
#
# <center>
#
# ![alt text](https://nci-media.cancer.gov/pdq/media/images/765174-571.jpg)
#
# </center>
#
# Una solución a este problema son las **NBI**, las cuales facilitan la visualización de la áreas de displasia por medio de la utilización de un sistema de filtros que estrecha la longitud de onda de la luz emitida. Los primeros prototipos cubrían tres bandas (400-430 nm, 530-550 nm y 600-620 nm). Actualmente, el equipo disponible se basa en dos bandas (415 nm y 540 nm), correspondientes a la luz azul y verde; a diferencia de los equipos de videoendoscopía convencional utilizan **luz blanca**, la cual es reflejada en los tejidos y recuperada por un CCD (dispositivo de cargas eléctricas interconectadas o Charge-Coupled Device) en el extremo de los endoscopios. Esta luz blanca cubre prácticamente todo el espectro de la luz visible, es decir desde los 400 nm a los 700 nm.
#
# Teniendo en cuenta las bases de la espectrometría, la luz azul, que es de longitud de onda corta, penetra muy poco en la pared del órgano y refleja, por lo tanto, las imágenes más superficiales. Esta luz es fuertemente absorbida por la hemoglobina. De esta manera se resalta la red capilar cercana a la superficie de la mucosa.
#
# <center>
#
# <img width="550px" src="http://www.medindiahospitals.com/medindiahospitals/uploads/2018/03/1-1.jpg">
#
# </center>
#
# El procedimiento es idéntico al de una endoscopia convencional con diferencia de que se debe presionar un botón que activa el sistema NBI cuando se llegue a un área de interés y volver a presionar al terminar. Esta imagen se puede complementar con escalado de imagen de 1 hasta 115 veces.
#
# Esta nueva herramienta (el NBI) tiene enormes potenciales a la hora de realizar un diagnóstico más preciso durante la endoscopía; sin embargo, esta novedosa técnica enfrenta algunas limitaciones. En primer lugar, es todavía de disponibilidad limitada y alto costo.
#
# Esta situación seguramente cambiará a medida que el sistema se difunda entre la población. También posee limitaciones técnicas, como la poca profundidad de campo, que no permite una visión más allá del sector observado. Esto no parecería ser de mayor impacto ya que el NBI busca evaluar zona por zona. Por las características propias de la luz utilizada, la presencia de materia fecal (color anaranjado) o sangre en la luz (color negro) puede alterar la correcta visualización de la mucosa.
#
# ### Bibliografía
#
# - Diccionario de cáncer del NCI. (2021). Retrieved 23 November 2021, from https://www.cancer.gov/espanol/publicaciones/diccionarios/diccionario-cancer/def/displasia
# - Pellisé, M., & Sáenz, R. (2008). Imágenes de banda estrecha o Narrow band imaging (NBI): una nueva era en endoscopía digestiva. Revista Médica Del Uruguay, (vol.24 no.1). Retrieved from http://www.scielo.edu.uy/scielo.php?script=sci_arttext&pid=S1688-03902008000100007

# %% [markdown]
# ___

# %% [markdown]
# ## **Leer un video de colondoscopia. Mostrar diferencias entre colondoscopia optica y NBI. Obtener características (frames, ancho, alto, profundidad con opencv u otro).**

# %% [markdown]
# <a href="https://docs.opencv.org/3.4/d4/d15/group__videoio__flags__base.html">All video flags in opencv</a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

cap = cv.VideoCapture('http://www.depeca.uah.es/colonoscopy_dataset/Hyperplasic/hyperplasic_01/videos/NBI.mp4')
if not cap.isOpened():
    print("Cannot open camera")
    exit()
frames = int(cap.get(cv.CAP_PROP_FPS))
length = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
width  = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT ))
print("los frames por segundo en el video son:",frames)
print("la cantidad de frames en el video es:",length)
print("la duración del video en segundos es:",length/frames,"s")
print("el ancho del video es:",width)
print("el alto del video es:",length)
# Out:
# los frames por segundo en el video son: 25
# la cantidad de frames en el video es: 351
# la duración del video en segundos es: 14.04 s
# el ancho del video es: 768
# el alto del video es: 351

# %%
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    img = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    # Display the resulting frame
    cv2_imshow(img)
    if cv.waitKey(1) == ord('q'):
        break
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# ## Usar Mobilenetv2 para clasificar los elementos del dataset.

# %%
# Instalar beautifuldoup para la extracción de urls de todos los videos del 
# dataset que serán organizados en una lista para analizar con opencv y así
# generar un dataset de imagene a partir de los videos
# !pip install beautifulsoup4

# %%
import urllib.request
from bs4 import BeautifulSoup

opener = urllib.request.FancyURLopener({})
base_url = "http://www.depeca.uah.es/colonoscopy_dataset/"
f = opener.open(base_url)
html = str(f.read())
soup = BeautifulSoup(html)

hyperplasic_wl = []
hyperplasic_nbi = []
serrated_wl = []
serrated_nbi = []
adenoma_wl = []
adenoma_nbi = []

for a in soup.find_all('a', href=True):
    if '.mp4' in a['href']:
        url = base_url+a['href']
        if 'Hyperplasic' in url:
            if 'WL' in url:
                hyperplasic_wl.append(url)
            elif 'NBI' in url:
                hyperplasic_nbi.append(url)
        elif 'Serrated' in url:
            if 'WL' in url:
                serrated_wl.append(url)
            elif 'NBI' in url:
                serrated_nbi.append(url)
        elif 'Adenoma' in url:
            if 'WL' in url:
                adenoma_wl.append(url)
            elif 'NBI' in url:
                adenoma_nbi.append(url)

print(hyperplasic_wl)
print(hyperplasic_nbi)
print(serrated_wl)
print(serrated_nbi)
print(adenoma_wl)
print(adenoma_nbi)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: FancyURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   after removing the cwd from sys.path.
# ...

# %%
print(len(hyperplasic_wl))
print(len(hyperplasic_nbi))
print(len(serrated_wl))
print(len(serrated_nbi))
print(len(adenoma_wl))
print(len(adenoma_nbi))
# Out:
# 21
# 21
# 15
# 15
# 40
# 40

# %%
nbi_lists = [hyperplasic_nbi,serrated_nbi,adenoma_nbi]

# %%
#Mount at content/data or create the directory if doesnt exists
import os
path = '/content/data'
try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory failed")
else:
    print ("Successfully created the directory")
os.chdir(path)
print(os.getcwd())
# Out:
# Creation of the directory failed
# /content/data

# %%
import cv2 as cv

labels = ['hyperplastic','serrated','adenoma']
file_type = '.jpg'
i = 0
for term in labels:
    os.chdir(path)
    try:
        os.mkdir(term)
    except OSError:
        continue
    if (path=='/'):
        os.chdir(path+term+'/')
    else:
        os.chdir(path+'/'+term)
    
    j=0
    for url in nbi_lists[i]:
        img_name = term+str(j+1)
        print(img_name)
        cap = cv.VideoCapture(url)
        if not cap.isOpened():
            print("Cannot open camera")
            exit()
        k = 1
        while True:
            # Capture frame-by-frame
            ret, frame = cap.read()
            # if frame is read correctly ret is True
            if not ret:
                print("Can't receive frame (stream end?). Exiting ...")
                break
            # Our operations on the frame come here
            img = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
            # Saves the resulting frame
            cv.imwrite(img_name+'frame'+str(k)+file_type,img)
            if cv.waitKey(1) == ord('q'):
                break
            k = k + 1
        # When everything done, release the capture
        cap.release()
        cv.destroyAllWindows()
        j = j + 1
    i = i + 1

# %%
os.chdir(path+'/adenoma')
# !ls
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# adenoma17frame216.jpg	adenoma25frame310.jpg	adenoma38frame373.jpg
# adenoma17frame217.jpg	adenoma25frame311.jpg	adenoma38frame374.jpg
# adenoma17frame218.jpg	adenoma25frame312.jpg	adenoma38frame375.jpg
# adenoma17frame219.jpg	adenoma25frame313.jpg	adenoma38frame376.jpg
# adenoma17frame21.jpg	adenoma25frame314.jpg	adenoma38frame377.jpg
# adenoma17frame220.jpg	adenoma25frame315.jpg	adenoma38frame378.jpg
# adenoma17frame221.jpg	adenoma25frame316.jpg	adenoma38frame379.jpg
# adenoma17frame222.jpg	adenoma25frame317.jpg	adenoma38frame37.jpg
# adenoma17frame223.jpg	adenoma25frame318.jpg	adenoma38frame380.jpg
# adenoma17frame224.jpg	adenoma25frame319.jpg	adenoma38frame381.jpg
# adenoma17frame225.jpg	adenoma25frame31.jpg	adenoma38frame382.jpg
# adenoma17frame226.jpg	adenoma25frame320.jpg	adenoma38frame383.jpg
# adenoma17frame227.jpg	adenoma25frame321.jpg	adenoma38frame384.jpg
# ...

# %%
from google.colab.patches import cv2_imshow

cap = cv.VideoCapture('adenoma32frame303.jpg')
if not cap.isOpened():
    print("Cannot open camera")
    exit()
ret, frame = cap.read()
# Our operations on the frame come here
img = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
# Display the resulting frame
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F5006F9B610>

# %%
classes_names = os.listdir('/content/data/')
print(classes_names)
print('numero de clases: ',len(classes_names))
# Out:
# ['serrated', 'adenoma', 'hyperplastic']
# numero de clases:  3

# %%
# importar librerías necesarias
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import requests

import keras
from keras.models import Sequential
from keras import layers
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
)

# %%
#Makes a list of all the samples with its path
def dir_list(classes_names,path_classes):
  list_dirs = []
  for i, name_class in enumerate(classes_names):
    list_dirs = list_dirs +[name_class+ "/"+ s for s in (os.listdir(path_classes + '/' + classes_names[i]))]
  list_dirs = np.array(list_dirs)
  return list_dirs

#Makes a list of all the samples with its corresponding label
def dir_list_class(classes_names,list_dirs):
  s=[]
  s_code=[]
  i = 0
  for name in classes_names:
    patron = name+'/'
    for img in list_dirs:
      if (img.startswith(patron)):
        s.append(name)
        s_code.append(i)
    i = i + 1
  files_class = pd.DataFrame(list_dirs,columns=['files'])
  files_class['class_name'] = pd.Series(s)
  files_class['class'] = pd.Series(s_code)
  return files_class

# %%
list_dirs = dir_list(classes_names,path) 
print("First element:",list_dirs[0], "  |  shape:",list_dirs.shape)
print('Total elements:', len(list_dirs))
# Out:
# First element: serrated/serrated11frame296.jpg   |  shape: (38764,)
# Total elements: 38764

# %%
files_class = dir_list_class(classes_names,list_dirs)
files_class['files'] = '/content/data/' + files_class['files']
files_class
# Out:
#                                                    files    class_name  class
# 0          /content/data/serrated/serrated11frame296.jpg      serrated      0
# 1          /content/data/serrated/serrated13frame304.jpg      serrated      0
# 2            /content/data/serrated/serrated5frame34.jpg      serrated      0
# 3            /content/data/serrated/serrated5frame53.jpg      serrated      0
# 4           /content/data/serrated/serrated8frame106.jpg      serrated      0
# ...                                                  ...           ...    ...
# 38759  /content/data/hyperplastic/hyperplastic15frame...  hyperplastic      2
# 38760  /content/data/hyperplastic/hyperplastic12frame...  hyperplastic      2
# 38761  /content/data/hyperplastic/hyperplastic8frame8...  hyperplastic      2
# 38762  /content/data/hyperplastic/hyperplastic1frame2...  hyperplastic      2
# 38763  /content/data/hyperplastic/hyperplastic1frame2...  hyperplastic      2
#
# [38764 rows x 3 columns]

# %%
#classifies files in train or test
train_percent = 0.7
files_class["train"] = '0'
initial_position_train = 0
for class_name in classes_names:
  class_len = len(files_class[files_class["class_name"]==class_name])
  end_position_train = int(class_len*train_percent)+initial_position_train
  files_class["train"][initial_position_train:end_position_train] = 1
  print(initial_position_train)
  initial_position_train = initial_position_train + class_len + 1
  print(end_position_train)
  print("___")
# Out:
# 0
# 5058
# ___
# 7228
# 23551
# ___
# 30548
# 36300
# ___
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
files_class
# Out:
#                                                    files  ... train
# 0          /content/data/serrated/serrated11frame296.jpg  ...     1
# 1          /content/data/serrated/serrated13frame304.jpg  ...     1
# 2            /content/data/serrated/serrated5frame34.jpg  ...     1
# 3            /content/data/serrated/serrated5frame53.jpg  ...     1
# 4           /content/data/serrated/serrated8frame106.jpg  ...     1
# ...                                                  ...  ...   ...
# 38759  /content/data/hyperplastic/hyperplastic15frame...  ...     0
# 38760  /content/data/hyperplastic/hyperplastic12frame...  ...     0
# 38761  /content/data/hyperplastic/hyperplastic8frame8...  ...     0
# 38762  /content/data/hyperplastic/hyperplastic1frame2...  ...     0
# 38763  /content/data/hyperplastic/hyperplastic1frame2...  ...     0
#
# [38764 rows x 4 columns]

# %%
train_dataset = files_class[files_class["train"] == 1]
test_dataset = files_class[files_class["train"] == "0"]

print("train len: ", len(train_dataset))
print("test len: ", len(test_dataset))
# Out:
# train len:  27133
# test len:  11631

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 64

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255, 
    validation_split=0.2
)

train_generator = datagen.flow_from_dataframe(
    train_dataset[["files","class_name"]],
    x_col='files', y_col='class_name',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

val_generator = datagen.flow_from_dataframe(
    test_dataset[["files","class_name"]],
    x_col='files', y_col='class_name',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 27133 validated image filenames belonging to 3 classes.
# Found 11631 validated image filenames belonging to 3 classes.

# %%
image_batch, label_batch = next(val_generator)
image_batch.shape, label_batch.shape
# Out:
# ((64, 224, 224, 3), (64, 3))

# %%
IMG_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)

# Create the base model from the pre-trained MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                              include_top=False, 
                                              weights='imagenet')
base_model.trainable = False
# Out:
# ...
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
model = tf.keras.Sequential([
  base_model,
  tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dense(units=3, activation='softmax')
])

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 32)          368672
#
#  dropout_1 (Dropout)         (None, 5, 5, 32)          0
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 3)                 99
#
# ...
# Total params: 2,626,755
# Trainable params: 368,771
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
history = model.fit(train_generator,
                    steps_per_epoch=len(train_generator), 
                    epochs=10,
                    validation_data=val_generator,
                    validation_steps=len(val_generator))
# Out:
# Epoch 1/10
# 424/424 [==============================] - 304s 709ms/step - loss: 0.4867 - accuracy: 0.8378 - val_loss: 0.1617 - val_accuracy: 0.9451
# Epoch 2/10
# 424/424 [==============================] - 293s 691ms/step - loss: 0.1017 - accuracy: 0.9654 - val_loss: 0.0793 - val_accuracy: 0.9728
# Epoch 3/10
# 424/424 [==============================] - 300s 709ms/step - loss: 0.0634 - accuracy: 0.9770 - val_loss: 0.0909 - val_accuracy: 0.9672
# Epoch 4/10
# 424/424 [==============================] - 306s 722ms/step - loss: 0.0508 - accuracy: 0.9802 - val_loss: 0.0458 - val_accuracy: 0.9825
# Epoch 5/10
# 424/424 [==============================] - 306s 721ms/step - loss: 0.0420 - accuracy: 0.9846 - val_loss: 0.0396 - val_accuracy: 0.9859
# Epoch 6/10
# 424/424 [==============================] - 302s 712ms/step - loss: 0.0293 - accuracy: 0.9884 - val_loss: 0.0415 - val_accuracy: 0.9836
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
